# %%
import numpy as np
import pandas as pd

# %%
ds = pd.read_csv('./sales_data_training.csv')
print ds.shape
ds.head()
# Out:
# (1000, 10)
#    critic_rating  is_action  is_exclusive_to_us  is_portable  is_role_playing  \
# 0            3.5          1                   0            1                0
# 1            4.5          0                   0            0                0
# 2            3.0          0                   0            0                0
# 3            4.5          1                   0            0                0
# 4            4.0          1                   0            1                0
#
#    is_sequel  is_sports  suitable_for_kids  total_earnings  unit_price
# 0          1          0                  0          132717       59.99
# 1          1          1                  0           83407       49.99
# 2          1          1                  0           62423       49.99
# 3          0          0                  1           69889       39.99
# 4          1          0                  1          161382       59.99

# %%
ds_test = pd.read_csv('./sales_data_test.csv')
print ds_test.shape
ds_test.head()
# Out:
# (400, 10)
#    critic_rating  is_action  is_exclusive_to_us  is_portable  is_role_playing  \
# 0            3.5          1                   1            1                0
# 1            2.5          0                   0            0                1
# 2            3.5          0                   0            0                0
# 3            4.0          1                   1            0                0
# 4            2.0          1                   0            1                0
#
#    is_sequel  is_sports  suitable_for_kids  total_earnings  unit_price
# 0          1          0                  1          247537       59.99
# 1          1          0                  0           73960       59.99
# 2          1          1                  0           82671       59.99
# 3          1          0                  0          137456       39.99
# 4          1          0                  0           89639       59.99
