# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img_path = './images/anf_64540_01_model1.jpg'
mask_path = './images/anf_64540_01_model1_Mask_front_inspect.png'

# %%
img = Image.open(img_path)
print type(img)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
img_arr = np.array(img)
print type(img_arr)
# Out:
# <type 'numpy.ndarray'>

# %%
plt.imshow(img)
plt.show()
print img_arr.shape
# Out:
# (1200, 1200, 3)

# %%
mask = Image.open(mask_path)

# %%
print np.unique(np.array(mask))
# Out:
# [0 1 2 3 6 7]

# %%
x = np.array(mask)
plt.imshow(x)
plt.show()
print x.shape
# Out:
# (512, 512)

# %%
plt.imshow(x==1)
plt.show()

# %%
img_res = cv2.resize(img_arr, (512, 512))
print img_res.shape
# Out:
# (512, 512, 3)

# %%
roi = np.array(x==1).reshape((512, 512, 1))
ans = img_res*roi

# %%
plt.imshow(ans)
plt.show()
