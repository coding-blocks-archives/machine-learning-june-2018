# %%
import pandas as pd
import numpy as np

# %%
path = '/Users/ayush/Desktop/WQ.csv'

# %%
data = pd.read_csv(path)
data.head(n=20)
# Out:
#     Unnamed: 0       Fnum              Name Gend Cate Minority  KM   CW  PWD  \
# 0           89  180088223     VARUN  SIRPAL    M   UR      NaN NaN  NaN  NaN
# 1          195  180073739           ARJUN      M  OBC      NaN NaN  NaN  NaN
# 2          814  180111832      RIYA  THAPAR    F   UR      NaN NaN  NaN  NaN
# 3         1197  180181534   AANCHAL   VERMA    F   UR      NaN NaN  NaN  NaN
# 4         1287  180139840      SIMRAN  KAUR    F   UR     Sikh NaN  NaN  NaN
# 5         1336  180227435  HIMANSHU  MISHRA    M   UR      NaN NaN  NaN  NaN
# 6         1353  180093012     RAKESH  KUMAR    M  OBC      NaN NaN  NaN  NaN
# 7         1566  180251648     KAVISH  MEENA    M   ST      NaN NaN  NaN  NaN
# 8         2583  180324875   SAKSHAM  TANEJA    M   UR      NaN NaN  NaN  NaN
# 9         2635  180081631     RACHIT  HURIA    M   UR      NaN NaN  NaN  NaN
# 10        3776  180010113   PRAGYA   JINDAL    F   UR      NaN NaN  NaN  NaN
# ...

# %%
eco_marks = marks.get('Econ')
inf = [data.get('Econ'), data.get('BOF')]
eco = data.get('Econ')
bof = data.get('BOF')
print len(eco)
inf = []
for ix in range(len(bof)):
    inf.append((eco[ix], bof[ix]))
print len(inf)
ans = sorted(inf, key=lambda z:z[1], reverse=True)
print len(ans)
# Out:
# 273
# 273
# 273

# %%
for key in ans[:20]:
    print key
# Out:
# (99, 99.0)
# (100, 98.75)
# (99, 98.25)
# (100, 98.25)
# (99, 97.75)
# (98, 97.5)
# (98, 97.5)
# (99, 97.25)
# (98, 96.75)
# (95, 96.75)
# (97, 96.75)
# (97, 96.25)
# (100, 96.0)
# (96, 95.75)
# (93, 95.75)
# (97, 95.5)
# (97, 95.5)
# (0, 95.25)
# (97, 95.25)
# (95, 95.25)

# %%
my_info = inf[0]
print len(my_info)
# Out:
# 2

# %%
info = data.values
print info.shape
# Out:
# (273, 17)

# %%
marks = data.get('BOF')

# %%
print len(marks)
# Out:
# 273

# %%
mark2 = np.array(marks)

# %%
ans = sorted(mark2, reverse=True)
ans = np.array(ans)

# %%
limit = np.sum(np.array(ans>=97.25))

# %%
for m in ans[:limit]:
    print m,
# Out:
# 99.0 98.75 98.25 98.25 97.75 97.5 97.5 97.25

# %%
ans[limit:1]
