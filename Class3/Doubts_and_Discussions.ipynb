# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
x = np.ones((5,2))
print x.shape
# Out:
# (5, 2)

# %%
x2 = np.sum(x)
print x2
x3 = np.sum(x, axis=0)
print x3
x4 = np.sum(x, axis=1)
print x4
# Out:
# 10.0
# [5. 5.]
# [2. 2. 2. 2. 2.]

# %%
img = cv2.imread('/Users/ayush/Downloads/redbag.jpg')
print img.shape
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# (240, 180, 3)

# %%
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
